# %% [markdown]
# <a href="https://colab.research.google.com/github/amitderei/BPark/blob/main/MyFirstColabNotebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
print(time.ctime())
# Out:
# Tue Oct 28 09:01:43 2025

# %%
time.sleep(5)
print (time.ctime())
# Out:
# Tue Oct 28 09:01:48 2025
